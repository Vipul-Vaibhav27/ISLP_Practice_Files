# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from ISLP import load_data

# %%
Boston = load_data("Boston")

# %%
Boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %%
Boston.shape
# Out:
# (506, 13)

# %%
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
pd.plotting.scatter_matrix(Boston[["crim", "zn", "medv"]]);

# %%
pd.plotting.scatter_matrix(Boston);

# %%
pd.plotting.scatter_matrix(Boston[["rad", "tax", "medv"]]);

# %%
pd.plotting.scatter_matrix(Boston[["medv", "lstat"]])
# Out:
# array([[<Axes: xlabel='medv', ylabel='medv'>,
#         <Axes: xlabel='lstat', ylabel='medv'>],
#        [<Axes: xlabel='medv', ylabel='lstat'>,
#         <Axes: xlabel='lstat', ylabel='lstat'>]], dtype=object)

# %%
plt.scatter(Boston["nox"], Boston["medv"], marker="x", color="red")

# %%
pd.plotting.scatter_matrix(Boston[["zn", "indus", "dis", "medv"]]);

# %%
Boston[Boston.crim>50]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
#
#      ptratio  lstat  medv
# 380     20.2  17.21  10.4
# 405     20.2  22.98   5.0
# 410     20.2  10.11  15.0
# 418     20.2  20.62   8.8

# %%
Boston.max()
# Out:
# crim        88.9762
# zn         100.0000
# indus       27.7400
# chas         1.0000
# nox          0.8710
# rm           8.7800
# age        100.0000
# dis         12.1265
# rad         24.0000
# tax        711.0000
# ptratio     22.0000
# lstat       37.9700
# medv        50.0000
# dtype: float64

# %%
Boston.min()
# Out:
# crim         0.00632
# zn           0.00000
# indus        0.46000
# chas         0.00000
# nox          0.38500
# rm           3.56100
# age          2.90000
# dis          1.12960
# rad          1.00000
# tax        187.00000
# ptratio     12.60000
# lstat        1.73000
# medv         5.00000
# dtype: float64

# %%
np.sum(Boston.chas==1) # 35 o. of suburbs in this data set bound the Charles River
# Out:
# 35

# %%
Boston.ptratio.median() # Median is 19.05
# Out:
# 19.05

# %%
Boston[Boston.medv.min()==Boston.medv] # these suburbs has lowest median value of owner occupied homes
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %% [markdown]
# crim rate is high, zn is 0, indus is 18.1 o fboth, both don't bound river
# nitrogen levels are pretty high, rm is petty low, dis is pretty low
# rad is highest, tax is pretty high, lstat is really high
#
# Describing predictors of above both suburbs

# %%
np.sum(Boston.rm>7) # 64 such subrubs
# Out:
# 64

# %%
np.sum(Boston.rm>8) # 13 such suburbs
# Out:
# 13

# %%
Boston[Boston.rm>8]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %% [markdown]
# Above suburbs have pretty low and medv is really high, dis is low-mid, pt ratio is mid, lstat is low, age is pretty high, nox is mid-high, indus is low
